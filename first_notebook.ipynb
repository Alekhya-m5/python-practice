# %%
print("VS Setup done and i will start my ml journey!!!🚀")
# Out:
# VS Setup done and i will start my ml journey!!!🚀

# %%
import pandas as pd
import numpy as np
df=pd.DataFrame({
    "Name":["Alekhya","Sanjeevini","Bhagya","Aaditi"],
    "CGPA":[9.51,8.6,8.9,9.0]
})
print(df)
average=df['CGPA'].mean()
print("Average CGPA:",average)
# Out:
#          Name  CGPA
# 0     Alekhya  9.51
# 1  Sanjeevini  8.60
# 2      Bhagya  8.90
# 3      Aaditi  9.00
# Average CGPA: 9.0025

# %%
from sklearn.linear_model import LinearRegression
import numpy as np
import matplotlib.pyplot as plt
x=np.array([[1],[2],[3],[4],[5]])
y=np.array([2,4,6,8,10])
plt.scatter(x,y)
model=LinearRegression()
model.fit(x,y)
print(model.predict([[7]]))
# Out:
# [14.]

# %%
from sklearn.datasets import load_diabetes
data = load_diabetes(as_frame=True)
print(data)
# Out:
# {'data':           age       sex       bmi        bp        s1        s2        s3  \
# 0    0.038076  0.050680  0.061696  0.021872 -0.044223 -0.034821 -0.043401
# 1   -0.001882 -0.044642 -0.051474 -0.026328 -0.008449 -0.019163  0.074412
# 2    0.085299  0.050680  0.044451 -0.005670 -0.045599 -0.034194 -0.032356
# 3   -0.089063 -0.044642 -0.011595 -0.036656  0.012191  0.024991 -0.036038
# 4    0.005383 -0.044642 -0.036385  0.021872  0.003935  0.015596  0.008142
# ..        ...       ...       ...       ...       ...       ...       ...
# 437  0.041708  0.050680  0.019662  0.059744 -0.005697 -0.002566 -0.028674
# 438 -0.005515  0.050680 -0.015906 -0.067642  0.049341  0.079165 -0.028674
# 439  0.041708  0.050680 -0.015906  0.017293 -0.037344 -0.013840 -0.024993
# 440 -0.045472 -0.044642  0.039062  0.001215  0.016318  0.015283 -0.028674
# 441 -0.045472 -0.044642 -0.073030 -0.081413  0.083740  0.027809  0.173816
#
#            s4        s5        s6
# 0   -0.002592  0.019907 -0.017646
# ...

# %%
import pandas as pd
df=data.frame
print(df.head())
# Out:
#         age       sex       bmi        bp        s1        s2        s3  \
# 0  0.038076  0.050680  0.061696  0.021872 -0.044223 -0.034821 -0.043401
# 1 -0.001882 -0.044642 -0.051474 -0.026328 -0.008449 -0.019163  0.074412
# 2  0.085299  0.050680  0.044451 -0.005670 -0.045599 -0.034194 -0.032356
# 3 -0.089063 -0.044642 -0.011595 -0.036656  0.012191  0.024991 -0.036038
# 4  0.005383 -0.044642 -0.036385  0.021872  0.003935  0.015596  0.008142
#
#          s4        s5        s6  target
# 0 -0.002592  0.019907 -0.017646   151.0
# 1 -0.039493 -0.068332 -0.092204    75.0
# 2 -0.002592  0.002861 -0.025930   141.0
# 3  0.034309  0.022688 -0.009362   206.0
# 4 -0.002592 -0.031988 -0.046641   135.0

# %%
df.isnull().sum()
# Out:
# age       0
# sex       0
# bmi       0
# bp        0
# s1        0
# s2        0
# s3        0
# s4        0
# s5        0
# s6        0
# target    0
# dtype: int64

# %%
import pandas as pd
df=pd.DataFrame(data.data,columns=data.feature_names)

df['target']=data.target
print(df.head())
# Out:
#         age       sex       bmi        bp        s1        s2        s3  \
# 0  0.038076  0.050680  0.061696  0.021872 -0.044223 -0.034821 -0.043401
# 1 -0.001882 -0.044642 -0.051474 -0.026328 -0.008449 -0.019163  0.074412
# 2  0.085299  0.050680  0.044451 -0.005670 -0.045599 -0.034194 -0.032356
# 3 -0.089063 -0.044642 -0.011595 -0.036656  0.012191  0.024991 -0.036038
# 4  0.005383 -0.044642 -0.036385  0.021872  0.003935  0.015596  0.008142
#
#          s4        s5        s6  target
# 0 -0.002592  0.019907 -0.017646   151.0
# 1 -0.039493 -0.068332 -0.092204    75.0
# 2 -0.002592  0.002861 -0.025930   141.0
# 3  0.034309  0.022688 -0.009362   206.0
# 4 -0.002592 -0.031988 -0.046641   135.0

# %%
from sklearn.linear_model import LinearRegression
x=df.drop('target',axis=1)
y=df['target']
model=LinearRegression()
model.fit(x,y)
# new_patient=[[0.05, 0.02, 0.03, 0.04, -0.01, 0.02, 0.01, 0.03, 0.02, -0.02]]
print(model.predict([x.iloc[1]]))
# Out:
# [68.07103297]
# c:\Users\Acer\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
import pandas as pd

compare = pd.DataFrame({
    "Actual": y[:10],
    "Predicted": model.predict(x)[:10]
})

print(compare)
# Out:
#    Actual   Predicted
# 0   151.0  206.116677
# 1    75.0   68.071033
# 2   141.0  176.882790
# 3   206.0  166.914458
# 4   135.0  128.462258
# 5    97.0  106.351914
# 6   138.0   73.891347
# 7    63.0  118.854230
# 8   110.0  158.808897
# 9   310.0  213.584624

# %%
from sklearn.metrics import r2_score

pred = model.predict(x)
print(r2_score(y,pred))
# Out:
# 0.5177484222203498
